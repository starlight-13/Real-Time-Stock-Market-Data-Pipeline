# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test',
     bootstrap_servers=['15.207.111.151:9092'],
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
# !pip install s3fs
# Out:
# Requirement already satisfied: s3fs in /home/supernova/anaconda3/lib/python3.11/site-packages (2023.10.0)
# Requirement already satisfied: aiobotocore~=2.7.0 in /home/supernova/anaconda3/lib/python3.11/site-packages (from s3fs) (2.7.0)
# Requirement already satisfied: fsspec==2023.10.0 in /home/supernova/anaconda3/lib/python3.11/site-packages (from s3fs) (2023.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/supernova/anaconda3/lib/python3.11/site-packages (from s3fs) (3.9.3)
# Collecting botocore<1.31.65,>=1.31.16 (from aiobotocore~=2.7.0->s3fs)
#   Downloading botocore-1.31.64-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/supernova/anaconda3/lib/python3.11/site-packages (from aiobotocore~=2.7.0->s3fs) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/supernova/anaconda3/lib/python3.11/site-packages (from aiobotocore~=2.7.0->s3fs) (0.7.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/supernova/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/supernova/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/supernova/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/supernova/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/supernova/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.9.3)
# Requirement already satisfied: typing_extensions>=3.7 in /home/supernova/anaconda3/lib/python3.11/site-packages (from aioitertools<1.0.0,>=0.5.1->aiobotocore~=2.7.0->s3fs) (4.9.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/supernova/anaconda3/lib/python3.11/site-packages (from botocore<1.31.65,>=1.31.16->aiobotocore~=2.7.0->s3fs) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/supernova/anaconda3/lib/python3.11/site-packages (from botocore<1.31.65,>=1.31.16->aiobotocore~=2.7.0->s3fs) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /home/supernova/anaconda3/lib/python3.11/site-packages (from botocore<1.31.65,>=1.31.16->aiobotocore~=2.7.0->s3fs) (2.0.7)
# Requirement already satisfied: idna>=2.0 in /home/supernova/anaconda3/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.4)
# Requirement already satisfied: six>=1.5 in /home/supernova/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.31.65,>=1.31.16->aiobotocore~=2.7.0->s3fs) (1.16.0)
# Downloading botocore-1.31.64-py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: botocore
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.37.26
#     Uninstalling botocore-1.37.26:
#       Successfully uninstalled botocore-1.37.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# s3transfer 0.11.4 requires botocore<2.0a.0,>=1.37.4, but you have botocore 1.31.64 which is incompatible.
# boto3 1.37.26 requires botocore<1.38.0,>=1.37.26, but you have botocore 1.31.64 which is incompatible.
# Successfully installed botocore-1.31.64

# %%
for message in consumer:
    print(message)

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-project-ishita-bucket/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://kafka-stock-market-project-ishita-bucket/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1180, in KafkaConsumer.__next__(self)
#    1178     self._iterator = self._message_generator_v2()
#    1179 try:
# -> 1180     return next(self._iterator)
#    1181 except StopIteration:
#    1182     self._iterator = None
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1152, in KafkaConsumer._message_generator_v2(self)
#    1150 def _message_generator_v2(self):
#    1151     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1152     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1153     for tp, records in six.iteritems(record_map):
#    1154         # Generators are stateful, and it is possible that the tp / records
#    1155         # here may become stale during iteration -- i.e., we seek to a
#    1156         # different offset, pause consumption, or lose assignment.
#    1157         for record in records:
#    1158             # is_fetchable(tp) should handle assignment changes and offset
#    1159             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1160             # outer function destroying the existing iterator/generator
#    1161             # via self._iterator = None
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:688, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     686 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     687 while not self._closed:
# --> 688     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     689     if records:
#     690         return records
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:718, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     714     self._update_fetch_positions(self._subscription.missing_fetch_positions(), timeout_ms=inner_timeout_ms())
#     716 # If data is available already, e.g. from a previous network client
#     717 # poll() call to commit, then just return it immediately
# --> 718 records, partial = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#     719 # Before returning the fetched records, we can send off the
#     720 # next round of fetches and avoid block waiting for their
#     721 # responses to enable pipelining while the user is handling the
#     722 # fetched records.
#     723 if not partial:
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/fetcher.py:355, in Fetcher.fetched_records(self, max_records, update_offsets)
#     353         self._next_partition_records = self._parse_fetched_data(completion)
#     354     else:
# --> 355         records_remaining -= self._append(drained,
#     356                                           self._next_partition_records,
#     357                                           records_remaining,
#     358                                           update_offsets)
#     359 return dict(drained), bool(self._completed_fetches)
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/fetcher.py:398, in Fetcher._append(self, drained, part, max_records, update_offsets)
#     395     self._sensors.records_fetch_lag.record(highwater - part.next_fetch_offset)
#     396 if update_offsets or not part_records:
#     397     # TODO: save leader_epoch
# --> 398     log.debug("Updating fetch position for assigned partition %s to %s (leader epoch %s)",
#     399               tp, part.next_fetch_offset, part.leader_epoch)
#     400     self._subscriptions.assignment[tp].position = OffsetAndMetadata(part.next_fetch_offset, '', -1)
#     401 return len(part_records)
#
# File ~/anaconda3/lib/python3.11/logging/__init__.py:1467, in Logger.debug(self, msg, *args, **kwargs)
#    1464     self.level = _checkLevel(level)
#    1465     self.manager._clear_cache()
# -> 1467 def debug(self, msg, *args, **kwargs):
#    1468     """
#    1469     Log 'msg % args' with severity 'DEBUG'.
#    1470
#    (...)
#    1474     logger.debug("Houston, we have a %s", "thorny problem", exc_info=1)
#    1475     """
#    1476     if self.isEnabledFor(DEBUG):
#
# KeyboardInterrupt:

# %%
import s3fs

fs = s3fs.S3FileSystem(anon=False)

with fs.open('s3://kafka-stock-market-project-ishita-bucket/test-file.txt', 'w') as f:
    f.write("Testing S3 upload")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       1 import s3fs
#       3 fs = s3fs.S3FileSystem(anon=False)
# ----> 5 with fs.open('s3://kafka-stock-market-project-ishita-bucket/test-file.txt', 'w') as f:
#       6     f.write("Testing S3 upload")
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/spec.py:1942, in AbstractBufferedFile.close(self)
#    1940 else:
#    1941     if not self.forced:
# -> 1942         self.flush(force=True)
#    1944     if self.fs is not None:
#    1945         self.fs.invalidate_cache(self.path)
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/spec.py:1813, in AbstractBufferedFile.flush(self, force)
#    1810         self.closed = True
#    1811         raise
# -> 1813 if self._upload_chunk(final=force) is not False:
#    1814     self.offset += self.buffer.seek(0, 2)
#    1815     self.buffer = io.BytesIO()
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:2288, in S3File._upload_chunk(self, final)
#    2285     self.parts.append(part_header)
#    2287 if self.autocommit and final:
# -> 2288     self.commit()
#    2289 return not final
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:2306, in S3File.commit(self)
#    2304     if self.acl:
#    2305         kw["ACL"] = self.acl
# -> 2306     write_result = self._call_s3("put_object", **kw)
#    2307 else:
#    2308     raise RuntimeError
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:2151, in S3File._call_s3(self, method, *kwarglist, **kwargs)
#    2150 def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2151     return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:341, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     340 async def _call_s3(self, method, *akwarglist, **kwargs):
# --> 341     await self.set_session()
#     342     s3 = await self.get_s3(kwargs.get("Bucket"))
#     343     method = getattr(s3, method)
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:527, in S3FileSystem.set_session(self, refresh, kwargs)
#     523 else:
#     524     s3creator = self.session.create_client(
#     525         "s3", config=conf, **init_kwargs, **client_kwargs
#     526     )
# --> 527     self._s3 = await s3creator.__aenter__()
#     529 self._s3creator = s3creator
#     530 # the following actually closes the aiohttp connection; use of privates
#     531 # might break in the future, would cause exception at gc time
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/session.py:27, in ClientCreatorContext.__aenter__(self)
#      26 async def __aenter__(self) -> AioBaseClient:
# ---> 27     self._client = await self._coro
#      28     return await self._client.__aenter__()
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/session.py:211, in AioSession._create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     195 self._add_configured_endpoint_provider(
#     196     client_name=service_name,
#     197     config_store=config_store,
#     198 )
#     199 client_creator = AioClientCreator(
#     200     loader,
#     201     endpoint_resolver,
#    (...)
#     209     user_agent_creator=user_agent_creator,
#     210 )
# --> 211 client = await client_creator.create_client(
#     212     service_name=service_name,
#     213     region_name=region_name,
#     214     is_secure=use_ssl,
#     215     endpoint_url=endpoint_url,
#     216     verify=verify,
#     217     credentials=credentials,
#     218     scoped_config=self.get_scoped_config(),
#     219     client_config=config,
#     220     api_version=api_version,
#     221     auth_token=auth_token,
#     222 )
#     223 monitor = self._get_internal_component('monitor')
#     224 if monitor is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/client.py:76, in AioClientCreator.create_client(self, service_name, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, api_version, client_config, auth_token)
#      63 region_name, client_config = self._normalize_fips_region(
#      64     region_name, client_config
#      65 )
#      66 endpoint_bridge = ClientEndpointBridge(
#      67     self._endpoint_resolver,
#      68     scoped_config,
#    (...)
#      74     ),
#      75 )
# ---> 76 client_args = self._get_client_args(
#      77     service_model,
#      78     region_name,
#      79     is_secure,
#      80     endpoint_url,
#      81     verify,
#      82     credentials,
#      83     scoped_config,
#      84     client_config,
#      85     endpoint_bridge,
#      86     auth_token,
#      87     endpoints_ruleset_data,
#      88     partition_data,
#      89 )
#      90 service_client = cls(**client_args)
#      91 self._register_retries(service_client)
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/client.py:267, in AioClientCreator._get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     241 def _get_client_args(
#     242     self,
#     243     service_model,
#    (...)
#     256     # This is a near copy of ClientCreator. What's replaced
#     257     # is ClientArgsCreator->AioClientArgsCreator
#     258     args_creator = AioClientArgsCreator(
#     259         self._event_emitter,
#     260         self._user_agent,
#    (...)
#     265         user_agent_creator=self._user_agent_creator,
#     266     )
# --> 267     return args_creator.get_client_args(
#     268         service_model,
#     269         region_name,
#     270         is_secure,
#     271         endpoint_url,
#     272         verify,
#     273         credentials,
#     274         scoped_config,
#     275         client_config,
#     276         endpoint_bridge,
#     277         auth_token,
#     278         endpoints_ruleset_data,
#     279         partition_data,
#     280     )
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/args.py:96, in AioClientArgsCreator.get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#      91 serializer = botocore.serialize.create_serializer(
#      92     protocol, parameter_validation
#      93 )
#      94 response_parser = botocore.parsers.create_parser(protocol)
# ---> 96 ruleset_resolver = self._build_endpoint_resolver(
#      97     endpoints_ruleset_data,
#      98     partition_data,
#      99     client_config,
#     100     service_model,
#     101     endpoint_region_name,
#     102     region_name,
#     103     configured_endpoint_url,
#     104     endpoint,
#     105     is_secure,
#     106     endpoint_bridge,
#     107     event_emitter,
#     108 )
#     110 # Copy the session's user agent factory and adds client configuration.
#     111 client_ua_creator = self._session_ua_creator.with_client_config(
#     112     new_config
#     113 )
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/args.py:162, in AioClientArgsCreator._build_endpoint_resolver(self, endpoints_ruleset_data, partition_data, client_config, service_model, endpoint_region_name, region_name, endpoint_url, endpoint, is_secure, endpoint_bridge, event_emitter)
#     160 else:
#     161     eprv2_region_name = region_name
# --> 162 resolver_builtins = self.compute_endpoint_resolver_builtin_defaults(
#     163     region_name=eprv2_region_name,
#     164     service_name=service_name_raw,
#     165     s3_config=s3_config_raw,
#     166     endpoint_bridge=endpoint_bridge,
#     167     client_endpoint_url=endpoint_url,
#     168     legacy_endpoint_url=endpoint.host,
#     169 )
#     170 # botocore does not support client context parameters generically
#     171 # for every service. Instead, the s3 config section entries are
#     172 # available as client context parameters. In the future, endpoint
#     173 # rulesets of services other than s3/s3control may require client
#     174 # context parameters.
#     175 client_context = (
#     176     s3_config_raw if self._is_s3_service(service_name_raw) else {}
#     177 )
#
# TypeError: ClientArgsCreator.compute_endpoint_resolver_builtin_defaults() missing 2 required positional arguments: 'credentials' and 'account_id_endpoint_mode'
